# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose this because I want to investigate ___ using the available data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
My research question is: Which observable factors in the dataset are associated with better search ranking performance, and can these patterns help prioritize pages for review?

The decision is which pages or search results should be prioritized for further investigation. The action is to review and improve the pages that appear to have weaker search performance. A wrong recommendation could cause time and effort to be spent improving the wrong pages, while pages that actually need attention may be overlooked.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import glob

# Find CSV files in the repository
csv_files = glob.glob("**/*.csv", recursive=True)

print("CSV files found:")
for file in csv_files:
    print(file)
# Out:
# CSV files found:
# sample_data/mnist_test.csv
# sample_data/california_housing_train.csv
# sample_data/mnist_train_small.csv
# sample_data/california_housing_test.csv

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
The analysis can identify patterns and associations in the available data and may provide useful decision support for prioritizing pages for review. However, the analysis cannot by itself prove that one factor causes better or worse search performance. It also cannot prove that the findings will improve Google ranking or predict Google's ranking with certainty. Any conclusions will be limited to the data and variables available in the starter dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
from google.colab import drive
drive.mount('/content/drive')
